# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\esman\Documents\Github\mediguard\data\titck_drugs_extracted.csv")

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (15488, 3)

# %%
df.to_csv(r"C:\Users\esman\Documents\Github\mediguard\data\raw\drug_reference\titck_drugs_extracted.csv", index=False)
